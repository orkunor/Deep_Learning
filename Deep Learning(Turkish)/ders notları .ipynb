# %% [markdown]
# # Artificial Neural Network (ANN)
#
# YAPAY SİNİR AĞLARI :
#
# --NEURAL NETWORK GÖRECELİ OLARAK BİRAZ DAHA DİĞER MAKİNE ÖĞRENMELERİNE GÖRE YAVAŞ ÇALIŞMAKTAYDI ÖNCEDEN FAKAT ŞU AN BİLGİSAYARLARIN GELİŞMESİYLE DAHA ÇOK KULLANILMAYA BAŞLANDI
#
# --GİRDİ => SİSTEM f(x) => ÇIKTI ŞEKLİNDE BU YAPI GÖRÜLMEKTEDİR !!!
#
# --NÖRON BURADA BİZİM SİSTEMİMİZDİR
#
# --GİRDİLER YİNE BAĞIMSIZ DEĞİŞKEN ÇIKTILAR İSE BAĞIMLI DEĞİŞKENLERDİR!!!
#
# --VERİLER 0-1 ARASINDA GELMELİDİR STANDARDİZE EDERİZ
#
# --ÇIKTIMIZDA 0-1 ARALIĞINDA OLMALIDIR GENELDE !!
#
# --SİNAPSİSLERİMİZİN AĞIRLIKLARIYLA ÇARPILARAK GELEN SİNYAL BURADAN SİSTEME ULAŞACAK BU DA ÖNEMLİ
#
# --AKTİVASYON FONKSİYONU VAR NÖRONUN SİSTEMİN ÇALIŞMASI İÇİN KARAR VERMESİ İÇİN GEREKLİ OLAN ATEŞLEME GÜCÜDÜR ATEŞLENMESİ İÇİN BELİRLİ BİR SINIRA ULAŞMASI GEREKİR
#
# --NEURAL NETWORKLER DERİN ÖĞRENMENİN TEMELİNİ OLUŞTURMAKTADIR.
#
# --AKTİVASYON FONKSİYONU İÇİN BAZI FONKSİYONLAR DAHA ÇOK TERCİH EİLİYORLAR
#
# --ÖRNEĞİN SİGMOİD FONKSİYONU VARDIR LOGİSTİC REG4RESYONDA DA İNCELEMİŞTİK
#
# --THRESHOLD FUNCTİON'DA OLDUKÇA KULLANILIR BURADA BUNUN KULLANILMASI AKTİVASYON DEĞERİNİ AŞINCA DEĞERİN BİR ANDA 1 OLMASINDAN GELMEKTEDİR
#
# --SİGMOİD FONKSİYONLA BERABER ARADA BİR DEĞERDE DÖNDÜREBİLİYOR
#
# --TANH'DA KULLANILABİLİR...
#
# # YAPAY SİNİR AĞLARINDA KATMAN NEDİR BUNA BAKALIM ? (LAYER)
#
# --GİRİŞ KATMANI , GİZLİ KATMAN , ÇIKIŞ KATMANI
#
# --GİZLİ KATMAN MÜDAHELE EDEBİLDİĞİMİZ KISMIN DIŞINDA YANİ BİZİM MÜDAHALE EDEMEDİĞİMİZ KATMANDIR
#
# -- AĞIRLIKLARI İLE AKTİVASYON EDİLMESİ BURADA DA GEÇERLİ SİNYAL ATEŞLEYİP ATEŞLEMEYECEĞİ AKTİVASYON FONKSİYONUNA BAĞLI
#
# -- HER NÖRONDA AYNI FONKSİYON KULLANMAK ZORUNDA DEĞİLİZ FARKLI ŞEKİLDE YAPABİLİRİZ
#
# --DEĞİŞİK KATMANLARI OLDUĞUNU DÜŞÜN BURADA
#
# --HER BİR ALGI SEVİYESİ İÇİN DEĞİŞİK KATMLANLAR KURULABİLİR
#
# --AND GATE DÜŞÜN SADECE İKİSİ DE 1 OLDUĞUNDA DOĞRU OLUR
#
# --OR GATE KULLANARAK DA ANLAMAK İÇİN BİR ÖRNEK YAPTIK
#
# --XOR GATE
#
# --LİNEARLY SEPERABLE KAVRAMI KARŞIMIZA ÇIKIYOR
#
# # ANN NASIL ÖĞRENİR ? PERCEPTRON (ALGILAYICI) KAVRAMI .
#
# --BOY VE KİLO DEĞİŞİK AĞIRLIKLARLA ÇARPILARAK FORMÜL OLUŞTURULUYOR VE NÖRON'DAN CİNSİYET BULUNMAYA ÇALIŞIYOR BUNA GÖRE AKTİVASYON DEĞERİ BELİRLENİYOR !!
#
# --ÖĞRENMENİN BİRKÇA PARAMETRESİ VAR
#
# --W1,W2 VE THERSHOLD TEK NÖRON İÇİN 3 FARKLI ÖPRENECEĞİ ŞEY
#
# --PERCEPTRON BURADA DEVREYE GİRİYOR
#
# --YİNE VERİLERİMİZİ EĞİTİM VE TEST KÜMESİ OLARAK BÖLECEĞİZ
#
# --PERCEPTRON BURADA GERİ BESLEME YAPILARAK DOĞRU W1,W2 DEĞERLERİNİN SAPTANMASINI SAĞLIYOR !!
#
# --C = 1/2(GERÇEK-TAHMİN)^2 BU SAYEDE PERCEPTRON BULUNUR C DEĞERİ GERİ BESLEME YÖNÜYLE GÖNDERİLİR VE GÜNCELLEME YAPILIR W1,W2 İÇİN
#
# --MAKİNE ZAMAN İÇİNDE KENDİSİNİ EĞİTEREK GELİŞTİRECEKTİR
#
# --ÇOK KÖTÜ BİR ALGORİTMA OLSA BİLE SİSTEM KENDİNİ GELİŞTİRECEKTİR
#
# --C'Yİ CEZA OLARAK DÜŞÜN BURADA
#
# # GRADIENT DESCENDENT (GRADYAN ALÇALIŞ) :
#
# --OPTİMUM NOKTAYI ARAYARAK İLERLİYORUZ..
#
# --ARTIK HAREKET ETMEYECEK EN GOĞRU NOKTAYI ARIYORUZ
#
# # STOCHASTİC GRADIENT DESCENDENT :
#
# --GRADIENT DESCENDENT YEREL BİR OPTİMUMU YAKALAYARAK ORAYI SEÇEBİLİR HALBUKİ BAŞKA YEREL NOKTALARDA DA SEÇİM YAPABİLİRİZ BUNU KAÇIRABİLİR BU YÜZDEN FARKLI YAKLAŞIMLARI KULLANIRIZ
#
# -- STOCHASTİC ÖRNEĞE BAKILARAK YAPILAN YÖNTEMDİR ADIM ADIM YAPIYORUZ
#
# --BATCH(YIĞIN) YAKLAŞIMI İSE BÜTÜN YIĞINA BAKARAK SİSTEME GERİ BESLEME YAPIYOR. ÇOK FAZLA VERİ VARSA BİRAZ ZOR OLUR
#
# -- MİNİ BATCH YAKLAŞIMI İSE BATCHLERİ KÜÇÜK YIĞINLARA BÖLEREK İŞLEMİ YAPIYOR
#
#
# # GERİ YAYILIM (BACKPROPAGATION) :
#
# --YAPAY SİNİR AĞININ ÜZERİNDE 2 TÜR YAYILIM VARDI RBİRİ GİRİŞTEN ÇIKIŞA DOĞRU İLERİ YAYILIMLI AŞAMADIR
#
# --BİR DE ÇIKIŞTAN GİRİŞE DOĞRU YAYILIM VARDIR İKİ YÖNLÜ DE YAYILIM VARDIR
#
# --ADIM 1 : BÜTÜN AĞI RASGELE SAYILARLA (SIFIRA YAKIN AMA SIFIRDAN FARKLI) İLKENDİR.
#
# --ADIM 2 : VERİ KÜMESİNDEN İLK SATIR (HER ÖZNİTELİK BİR NÖRON OLACAK ŞEKİLDE) GİRİŞ KATMANINDAN VERİLİR
#
# --NOT : NEURAL NETWORKLER DUMMY VARİABLE'LARA KARŞI BAĞIŞIKLIĞA SAHİPTİRLER !!! NE KADAR VERİRSEN VER , ÖZNİTELİK ÇIKARIMINI KENDİ YAPIYOR... ÖNİŞLEMEYİ NEURAL NETWORK KENDİ YAPABİLİR... YETERKİ YETERLİ NÖRONU VER
#
# --ADIM 3 : İLERİ YÖNLÜ YAYILIM YAPARAK , ANN(YAPAY SİNİR AĞLARI) İSTENEN SONUCU VERENE KADAR GÜNCELLENİR.
#
# --ADIM 4 : GERÇEK VE ÇIKTI ARASINDAKİ FARK ALINARAK HATA(ERROR) HESAPLANIR...
#
# --ADIM 5 : GERİ YAYILIM YAPARAK , HER SİNAPSİS ÜZERİNDEKİ AĞIRLIK , HATADAN SORUMLU OLDUĞU MİKTARDA DEĞİŞTİRİLİR. DEĞİŞTİRİLME MİKTARI AYRICA ÖĞRENME ORANINA DA BAĞLIDIR
#
# --ADIM 6 : ADIM 1-5 ARASINDAKİ ADIMLARI İSTENEN SONUCU ELDE EDENE KADAR GÜNCELLE (REİNFORCED LEARNING) VEYA ELDEKİ BÜTÜN VEİRLERİ İLGİLİ AĞDA ÇALIŞTIRDIKTAN SONRA BİR SEFERDE GÜNCELLEME YAP (BATCH LEARNING) .
#
# --ADIM 7 : BÜTÜN EĞİTİM KÜMESİ ÇALIŞTIRILDIKTAN SONRA ÇAĞ/TUR(EPOCH) TAMAMLANMIŞ OLUR. AYNI VERİ KÜMELERİ KULLANILARAK EPOCH TEKRARLARI YAPILIR. EPOCH DEĞERİNİ DOĞRU VERMEMİZ GEREKİR ÇÜNKÜ FAZLA VERİRSEK BOŞA ÇALIŞIR AZ VERİRSEK DOĞRU ÖĞRENMEZ...
#
# --LEARININ RATE : HANGİ HIZDA ÖĞRENECEĞİDİR
#
# --EPOCH : VERİLER ÜZERİNDE KAÇ TUR ATACAĞIDIR...
#
# # DERİN ÖĞRENME KÜTÜPHANELERİ :
#
# --PYTORCH YENİ EKLENEN KÜTÜPHANELERDENDİR
#
# --KERAS ÜST SINIFTIR , AŞAĞIDA TENSORFLOW KULLANABİLİR...
#
# --DERİN ÖĞRENMENİN KULLANILDIĞI VE ÜZERİNDE ÇOK SAYIDA NÖRONUN OLDUĞU DURUMLARDA GPU'LAR ÇOK AVANTAJLIDIR
#
# --GPU'LAR GRAFİKLERİ GÖRSELLEŞTİRMEK İÇİN KULLANILIR DERİN ÖĞRENME DE BUNLARLA ÇALIŞTIĞI İÇİN ÇOK YARARLIDIR...
